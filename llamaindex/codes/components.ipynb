# %% [markdown]
# # Components in LlamaIndex
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)
#
# Alfred is hosting a party and needs to be able to find relevant information on personas that will be attending the party. Therefore, we will use a `QueryEngine` to index and search through a database of personas.
#
# ## Let's install the dependencies
#
# We will install the dependencies for this unit.

# %%
# !pip install llama-index datasets llama-index-callbacks-arize-phoenix arize-phoenix llama-index-vector-stores-chroma llama-index-llms-huggingface-api llama-index-embeddings-huggingface -U -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 89.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 91.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 92.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.3/129.3 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.2 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %% [markdown]
# And, let's log in to Hugging Face to use serverless Inference APIs.

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Create a `QueryEngine` for retrieval augmented generation
#
# ### Setting up the persona database
#
# We will be using personas from the [dvilasuero/finepersonas-v0.1-tiny dataset](https://huggingface.co/datasets/dvilasuero/finepersonas-v0.1-tiny). This dataset contains 5K personas that will be attending the party!
#
# Let's load the dataset and store it as files in the `data` directory

# %%
from datasets import load_dataset
from pathlib import Path

dataset = load_dataset(path="dvilasuero/finepersonas-v0.1-tiny", split="train")

Path("data").mkdir(parents=True, exist_ok=True)
for i, persona in enumerate(dataset):
    with open(Path("data") / f"persona_{i}.txt", "w") as f:
        f.write(persona["persona"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/618 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/35.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %% [markdown]
# Awesome, now we have a local directory with all the personas that will be attending the party, we can load and index!
#
# ### Loading and embedding persona documents
#
# We will use the `SimpleDirectoryReader` to load the persona descriptions from the `data` directory. This will return a list of `Document` objects.

# %%
dataset
# Out:
# Dataset({
#     features: ['id', 'persona', 'model_name_embeddings', 'embedding', 'nn_indices', 'nn_scores', 'projection', 'cluster_label', 'summary_label'],
#     num_rows: 5000
# })

# %%
persona
# Out:
# {'id': '<urn:uuid:4b463cdb-d10b-4634-943d-789aa0fa6a61>',
#  'persona': 'A medical professional specializing in oncology or a healthcare provider focused on patient education, likely an internist or a gastroenterologist, who prioritizes clear and concise communication of complex health information to patients.',
#  'model_name_embeddings': 'Alibaba-NLP/gte-large-en-v1.5',
#  'embedding': [-0.03687451407313347,
#   -0.008114331401884556,
#   -0.006511371117085218,
#   0.006908327806740999,
#   0.017953531816601753,
#   0.011432834900915623,
#   0.00039495425880886614,
#   0.0074589308351278305,
#   -0.0048296633176505566,
#   -0.0016417173901572824,
#   -0.011590508744120598,
#   -0.006339957471936941,
#   -0.008978557772934437,
#   -0.006717226002365351,
#   -0.0022173526231199503,
#   -0.021207941696047783,
#   0.02809717319905758,
#   -0.009009630419313908,
#   -0.006346428766846657,
#   -0.012153471820056438,
#   0.03864119201898575,
#   0.03268368914723396,
#   0.005661402828991413,
#   -0.05846736952662468,
#   -0.06825656443834305,
#   0.007479238323867321,
#   -0.019165297970175743,
#   -0.036716703325510025,
#   0.01608223281800747,
#   -0.004133746027946472,
#   -0.0056539904326200485,
#   0.00015330921451095492,
#   -0.027010787278413773,
#   0.026346763595938683,
#   -0.03383687511086464,
#   -0.00975739024579525,
#   -0.011458133347332478,
#   -0.028633221983909607,
#   0.0023026487324386835,
#   0.018380915746092796,
#   0.012539983727037907,
#   -0.03560327738523483,
#   0.008051332086324692,
#   0.04542763903737068,
#   -0.02217760682106018,
#   0.01067523192614317,
#   0.03074105642735958,
#   -0.0006994626019150019,
#   0.027901986613869667,
#   0.023635143414139748,
#   -0.02465640939772129,
#   0.0030332705937325954,
#   0.02055000700056553,
#   -0.007968053221702576,
#   -0.031883396208286285,
#   0.015955394133925438,
#   0.027974164113402367,
#   -0.02807501144707203,
#   0.03636137768626213,
#   0.0298672653734684,
#   -0.009645650163292885,
#   0.02494686469435692,
#   -0.009139839559793472,
#   -0.027332842350006104,
#   -0.0032633140217512846,
#   -0.0364813506603241,
#   0.0003962850896641612,
#   -0.018352825194597244,
#   -0.03327871114015579,
#   0.0311257503926754,
#   0.0011822041124105453,
#   0.03201254457235336,
#   -0.02420739270746708,
#   -0.010707799345254898,
#   0.011605547741055489,
#   -0.01479476597160101,
#   0.01073845848441124,
 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A local art historian and museum professional interested in 19th-century American art and the local cultural heritage of Cincinnati.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1c96a81c-047e-4e4f-9810-7e30ab47d456', embedding=None, metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An anthropologist or a cultural expert interested in the intricacies of Cypriot culture, history, and society, particularly someone who has spent considerable time researching and living in Cyprus to gain a deep understanding of its people, customs, and way of life.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='14d19a94-39ff-4d8f-b964-9a26f0bf589b', embedding=None, metadata={'file_path': '/content/data/persona_10.txt', 'file_name': 'persona_10.txt', 'file_type': 'text/plain', 'file_size': 207, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A social justice educator or activist focused on diversity, equity, and inclusion, likely working with families and communities to promote empathy and understanding of intersectional identity and oppression.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f66bf861-b5a0-4410-b77f-c736bbab4442', embedding=None, metadata={'file_path': '/content/data/persona_100.txt', 'file_name': 'persona_100.txt', 'file_type': 'text/plain', 'file_size': 107, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An environmental conservationist focused on wetland ecosystems and their role in mitigating climate change.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='69f3bbc8-e1b5-4b7a-b401-3b3dc1e316ee', embedding=None, metadata={'file_path': '/content/data/persona_1000.txt', 'file_name': 'persona_1000.txt', 'file_type': 'text/plain', 'file_size': 133, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A pulmonologist or respiratory specialist with a strong interest in educating patients about the respiratory system and its diseases.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f19c7c5b-818e-42f6-90ea-7b991b97d30a', embedding=None, metadata={'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A web developer or a web development student, likely in the early stages of their learning or career, with a strong focus on HTML, CSS, and website building.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='3058595d-73fb-430d-8a6a-3febecefb2fe', embedding=None, metadata={'file_path': '/content/data/persona_1002.txt', 'file_name': 'persona_1002.txt', 'file_type': 'text/plain', 'file_size': 122, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An ecologist specializing in climate change impacts on regional ecosystems, particularly those with diverse plant species.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='005c2548-b93b-4c83-bf3c-258d611c1885', embedding=None, metadata={'file_path': '/content/data/persona_1003.txt', 'file_name': 'persona_1003.txt', 'file_type': 'text/plain', 'file_size': 170, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A special education teacher or instructional specialist focused on inclusive education and assistive technology, likely working with students with diverse learning needs.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c9b22863-5aa6-4ec0-82d0-3fc82de3fb24', embedding=None, metadata={'file_path': '/content/data/persona_1004.txt', 'file_name': 'persona_1004.txt', 'file_type': 'text/plain', 'file_size': 160, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An environmental historian or urban planner focused on ecological conservation and sustainability, likely working in local government or a related organization.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='564e78e4-7517-40f3-8eac-13184a00347b', embedding=None, metadata={'file_path': '/content/data/persona_1005.txt', 'file_name': 'persona_1005.txt', 'file_type': 'text/plain', 'file_size': 85, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An historian focused on 19th-century Irish politics and the Irish Home Rule movement.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='dab2e2d2-656e-4c61-bebf-a2ca52ed11d0', embedding=None, metadata={'file_path': '/content/data/persona_1006.txt', 'file_name': 'persona_1006.txt', 'file_type': 'text/plain', 'file_size': 143, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A linguistics scholar specializing in the study of nouns and naming conventions, likely with an academic background in theoretical linguistics.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='73f9bb8a-7a3d-4670-b0f6-0a6f055dc4a1', embedding=None, metadata={'file_path': '/content/data/persona_1007.txt', 'file_name': 'persona_1007.txt', 'file_type': 'text/plain', 'file_size': 138, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A neurologist or medical professional familiar with hypotonia and its treatment options, likely working in a specialized neurology clinic.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f39c1ede-44e1-4f01-9abd-3352047bc669', embedding=None, metadata={'file_path': '/content/data/persona_1008.txt', 'file_name': 'persona_1008.txt', 'file_type': 'text/plain', 'file_size': 125, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A neuroscience or cognitive science writer focused on making complex brain-related research accessible to a general audience.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c474c52e-36ec-43d0-8fe0-82e3d11e2f36', embedding=None, metadata={'file_path': '/content/data/persona_1009.txt', 'file_name': 'persona_1009.txt', 'file_type': 'text/plain', 'file_size': 172, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A planetary geologist focused on Martian research and exploration, specifically studying the planet's subsurface composition and its implications for future human missions.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='9b2807ba-d885-47a8-a011-f098bb42113e', embedding=None, metadata={'file_path': '/content/data/persona_101.txt', 'file_name': 'persona_101.txt', 'file_type': 'text/plain', 'file_size': 163, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A wildlife ecologist or a forester with a focus on avian conservation, specifically interested in the behavior and habitat requirements of the pileated woodpecker.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='40af2fa5-94a6-47f5-9a53-7eadb0136125', embedding=None, metadata={'file_path': '/content/data/persona_1010.txt', 'file_name': 'persona_1010.txt', 'file_type': 'text/plain', 'file_size': 233, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An environmental activist focused on ocean conservation, likely working for or closely following organizations such as Oceana, and advocating for the protection of marine ecosystems and the cessation of destructive fishing practices.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7458e7b7-612a-432e-a1bb-23bec1980dff', embedding=None, metadata={'file_path': '/content/data/persona_1011.txt', 'file_name': 'persona_1011.txt', 'file_type': 'text/plain', 'file_size': 140, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A student of Indian history or politics, likely preparing for a competitive examination, focused on the country's struggle for independence.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='2f119d27-c807-44ce-9584-3d0848b2d3dc', embedding=None, metadata={'file_path': '/content/data/persona_1012.txt', 'file_name': 'persona_1012.txt', 'file_type': 'text/plain', 'file_size': 139, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A historical preservationist or a women's rights historian with a focus on the 19th-century women's suffrage movement in the United States.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='9fa76bb4-a5f1-4b55-a6d3-f3ae7dfcc2d5', embedding=None, metadata={'file_path': '/content/data/persona_1013.txt', 'file_name': 'persona_1013.txt', 'file_type': 'text/plain', 'file_size': 167, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A children's book author who writes biographical stories on influential historical figures, focusing on their formative years and the origins of their social activism.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='167c8cf4-54d9-498b-895c-9d4b0e51e736', embedding=None, metadata={'file_path': '/content/data/persona_1014.txt', 'file_name': 'persona_1014.txt', 'file_type': 'text/plain', 'file_size': 227, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A molecular biologist specializing in the origin of life and early evolution, likely with an academic or research background, and possibly working at the intersection of fields such as biochemistry, genetics, and phylogenetics.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b0e19188-a4b1-44d9-8bd6-78d8bf32134d', embedding=None, metadata={'file_path': '/content/data/persona_1015.txt', 'file_name': 'persona_1015.txt', 'file_type': 'text/plain', 'file_size': 212, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A neurologist or healthcare professional specializing in seizure disorders and epilepsy, likely working in an educational or advisory role, who aims to inform and support individuals affected by these conditions.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='754c11fe-9fdc-401c-bd24-545738b8a2bf', embedding=None, metadata={'file_path': '/content/data/persona_1016.txt', 'file_name': 'persona_1016.txt', 'file_type': 'text/plain', 'file_size': 185, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A literature student or academic specializing in American colonial literature, likely focusing on the works of the Puritan era and the role of religion in shaping these literary pieces.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='3e2440a2-015e-4719-aed2-bf4ccda5d0c1', embedding=None, metadata={'file_path': '/content/data/persona_1017.txt', 'file_name': 'persona_1017.txt', 'file_type': 'text/plain', 'file_size': 112, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An 18th-century history academic specializing in Leibniz studies and early modern European intellectual history.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='9afafcb4-1cf4-46c6-965a-68012ee0c45c', embedding=None, metadata={'file_path': '/content/data/persona_1018.txt', 'file_name': 'persona_1018.txt', 'file_type': 'text/plain', 'file_size': 165, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A researcher focused on economic statistics and wealth inequality analysis, likely affiliated with a government agency, academic institution, or economic think tank.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='2ff48e9a-233e-4ca8-a429-2e4395516384', embedding=None, metadata={'file_path': '/content/data/persona_1019.txt', 'file_name': 'persona_1019.txt', 'file_type': 'text/plain', 'file_size': 175, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A social studies educator in a K-12 setting, likely a department chair or curriculum specialist, focused on promoting critical thinking, civic competence, and literacy skills.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a1356494-849b-49bd-a220-199281b7635c', embedding=None, metadata={'file_path': '/content/data/persona_102.txt', 'file_name': 'persona_102.txt', 'file_type': 'text/plain', 'file_size': 112, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A literacy specialist or reading teacher focused on supporting students with reading comprehension difficulties.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='292b304d-745d-47a1-acbb-af9f17c1f2c3', embedding=None, metadata={'file_path': '/content/data/persona_1020.txt', 'file_name': 'persona_1020.txt', 'file_type': 'text/plain', 'file_size': 127, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An educational specialist in curriculum development and instructional design, likely with a focus on standards-based education.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='3a4123c3-a990-44de-8e95-f4cbe980abbb', embedding=None, metadata={'file_path': '/content/data/persona_1021.txt', 'file_name': 'persona_1021.txt', 'file_type': 'text/plain', 'file_size': 97, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A postgraduate student of education or an educational researcher with a background in philosophy.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1a82ea08-9878-41e5-8b47-085aae733641', embedding=None, metadata={'file_path': '/content/data/persona_1022.txt', 'file_name': 'persona_1022.txt', 'file_type': 'text/plain', 'file_size': 186, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An English literature teacher, likely with a specialization in poetry, whose writing style caters to educating students or enthusiasts about the fundamentals and various forms of poetry.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a97a0dc4-1d26-4baa-8789-341c9c227511', embedding=None, metadata={'file_path': '/content/data/persona_1023.txt', 'file_name': 'persona_1023.txt', 'file_type': 'text/plain', 'file_size': 161, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A student journalist or a social sciences writer, likely a university student themselves, with an interest in social issues, cultural diversity, and linguistics.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='74d14dfa-c18c-4d3e-b6ff-82698dbbe1ee', embedding=None, metadata={'file_path': '/content/data/persona_1024.txt', 'file_name': 'persona_1024.txt', 'file_type': 'text/plain', 'file_size': 134, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A computer science student or a C++ developer interested in learning and mastering various aspects of programming and data structures.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4e057759-fb0f-4499-94e5-e71df1b09897', embedding=None, metadata={'file_path': '/content/data/persona_1025.txt', 'file_name': 'persona_1025.txt', 'file_type': 'text/plain', 'file_size': 147, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A biology or pre-med student or a registered nurse, or a medical doctor who is an anatomy and physiology instructor or a cardiovascular researcher.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4dbe9843-471b-442c-b9f8-301dcce42060', embedding=None, metadata={'file_path': '/content/data/persona_1026.txt', 'file_name': 'persona_1026.txt', 'file_type': 'text/plain', 'file_size': 90, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A clinical psychologist or psychiatrist concerned with policy implementation and critique.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fa1e922f-84e4-48a4-9dd1-5bbee447ba34', embedding=None, metadata={'file_path': '/content/data/persona_1027.txt', 'file_name': 'persona_1027.txt', 'file_type': 'text/plain', 'file_size': 186, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A middle school language arts or foreign language teacher focused on developing interactive lesson plans and educational activities to engage students in grammar and vocabulary practice.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='48f32dc7-a0ca-4fc6-b905-08806faece60', embedding=None, metadata={'file_path': '/content/data/persona_1028.txt', 'file_name': 'persona_1028.txt', 'file_type': 'text/plain', 'file_size': 185, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An entomologist or a biology student interested in dipteran insects, likely with a focus on British wildlife and potentially involved in citizen science or ecological research projects.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='31286099-a184-49b8-a7fc-a056ae6bf178', embedding=None, metadata={'file_path': '/content/data/persona_1029.txt', 'file_name': 'persona_1029.txt', 'file_type': 'text/plain', 'file_size': 152, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An entomologist with a specialization in the cultural and historical impact of insects, particularly those that produce valuable dyes or other products.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='61adc78e-a445-4306-bfc9-51bc6edd7d85', embedding=None, metadata={'file_path': '/content/data/persona_103.txt', 'file_name': 'persona_103.txt', 'file_type': 'text/plain', 'file_size': 148, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A molecular biologist or a geneticist whose work involves DNA analysis and manipulation, likely with an interest in PCR techniques and applications.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c9e938a4-65b4-4498-884f-2609c7b25df2', embedding=None, metadata={'file_path': '/content/data/persona_1030.txt', 'file_name': 'persona_1030.txt', 'file_type': 'text/plain', 'file_size': 113, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An elementary school science teacher or educator responsible for creating interactive presentations for students.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b4eb943a-13b0-4cfa-ac6f-9acffe8cb145', embedding=None, metadata={'file_path': '/content/data/persona_1031.txt', 'file_name': 'persona_1031.txt', 'file_type': 'text/plain', 'file_size': 156, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An educator or educational researcher focused on culturally responsive teaching and assessment, particularly in diverse or multicultural classroom settings.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='90131259-9667-49dc-a907-7d9eb7e3e67a', embedding=None, metadata={'file_path': '/content/data/persona_1032.txt', 'file_name': 'persona_1032.txt', 'file_type': 'text/plain', 'file_size': 183, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An epidemiologist focused on mosquito-borne diseases, particularly dengue fever, who is also interested in the application of microbiological controls to prevent disease transmission.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d3936c5a-42ad-45b8-9857-617628265a8d', embedding=None, metadata={'file_path': '/content/data/persona_1033.txt', 'file_name': 'persona_1033.txt', 'file_type': 'text/plain', 'file_size': 227, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An education researcher or academic focused on pedagogy and instructional methods, likely with a background in educational psychology or curriculum development, who is also possibly a teacher educator or a university professor.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ba1c3fe1-96ca-4749-993f-3a109fe6b270', embedding=None, metadata={'file_path': '/content/data/persona_1034.txt', 'file_name': 'persona_1034.txt', 'file_type': 'text/plain', 'file_size': 108, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A fire safety inspector or instructor focused on the technical aspects of smoke detection and alarm systems.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c9680490-5001-4437-8ec3-8e9591043537', embedding=None, metadata={'file_path': '/content/data/persona_1035.txt', 'file_name': 'persona_1035.txt', 'file_type': 'text/plain', 'file_size': 148, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An ophthalmologist interested in educating patients about various eye infections and their treatments, or a medical writer specializing in eye care.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='863062f3-d7cf-4b1f-a8e0-2c1a07c7ea8c', embedding=None, metadata={'file_path': '/content/data/persona_1036.txt', 'file_name': 'persona_1036.txt', 'file_type': 'text/plain', 'file_size': 203, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A historian of Dutch-American relations, political science, and constitutional law, likely with a Ph.D. in History or a related field and affiliated with an academic institution or research organization.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c1eac9b9-3bdb-45df-9797-2248b3041c2c', embedding=None, metadata={'file_path': '/content/data/persona_1037.txt', 'file_name': 'persona_1037.txt', 'file_type': 'text/plain', 'file_size': 154, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A biomedical engineer focused on wearable technology and human-machine interfaces, or a researcher in the field of prosthetics and assistive technologies.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='48600349-2fcd-4c15-85e6-ea05fcef2e0c', embedding=None, metadata={'file_path': '/content/data/persona_1038.txt', 'file_name': 'persona_1038.txt', 'file_type': 'text/plain', 'file_size': 105, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A mathematics educator or academic with a focus on foundational geometric proofs and pedagogical clarity.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='5342f89a-5585-4780-aeab-d0d38388082a', embedding=None, metadata={'file_path': '/content/data/persona_1039.txt', 'file_name': 'persona_1039.txt', 'file_type': 'text/plain', 'file_size': 179, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An educator, likely a middle or high school teacher, focused on lesson planning and curriculum development across multiple subjects, including health, social studies, and science.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='11949ae3-32e7-4c5b-b5fe-9e9cc7409e08', embedding=None, metadata={'file_path': '/content/data/persona_104.txt', 'file_name': 'persona_104.txt', 'file_type': 'text/plain', 'file_size': 176, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A robotics engineer or a researcher in artificial intelligence and computer vision, specifically interested in bio-inspired navigation systems for autonomous robots and drones.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='db90fa3f-2954-4c11-b511-cb15374f10ad', embedding=None, metadata={'file_path': '/content/data/persona_1040.txt', 'file_name': 'persona_1040.txt', 'file_type': 'text/plain', 'file_size': 163, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A birder or ornithologist specializing in Warbler species, with a focus on their migration patterns and behaviors in North America, likely in the Minnesota region.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...
#  Document(id_='bb957655-7298-4da2-8401-db11f19ae305', embedding=None, metadata={'file_path': '/content/data/persona_1884.txt', 'file_name': 'persona_1884.txt', 'file_type': 'text/plain', 'file_size': 147, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A chemistry teacher explaining the process of aluminium extraction from its ore, bauxite, likely to students in a secondary or high school setting.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a7e54cb7-e7ab-43c4-b7c3-9f03ca9ef905', embedding=None, metadata={'file_path': '/content/data/persona_1885.txt', 'file_name': 'persona_1885.txt', 'file_type': 'text/plain', 'file_size': 146, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A materials scientist or optical physicist focused on the properties of anisotropic materials and their application in polarized light microscopy.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='bdbd991c-834b-47ab-8d52-977343202fa4', embedding=None, metadata={'file_path': '/content/data/persona_1886.txt', 'file_name': 'persona_1886.txt', 'file_type': 'text/plain', 'file_size': 138, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A special education researcher focused on the impact of labelling on children's development and advocating for a student-centric approach.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='54e22a1b-55b5-412e-9120-2305fc0bffa9', embedding=None, metadata={'file_path': '/content/data/persona_1887.txt', 'file_name': 'persona_1887.txt', 'file_type': 'text/plain', 'file_size': 146, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A middle school or high school science teacher focused on chemistry and physics, or possibly a science textbook author targeting a young audience.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='8e131493-4350-4bc4-be70-84881e9658fa', embedding=None, metadata={'file_path': '/content/data/persona_1888.txt', 'file_name': 'persona_1888.txt', 'file_type': 'text/plain', 'file_size': 115, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A human rights advocate focused on promoting girls' education and challenging gender-based discrimination globally.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b25c75bb-9138-40cb-a9b3-062a92836a3e', embedding=None, metadata={'file_path': '/content/data/persona_1889.txt', 'file_name': 'persona_1889.txt', 'file_type': 'text/plain', 'file_size': 138, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An herpetologist specializing in tropical ecosystems and conservation biology, particularly focused on endemic species and their habitats.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='772dd8e8-e0bb-41fe-8007-b7fa5f2b67bf', embedding=None, metadata={'file_path': '/content/data/persona_189.txt', 'file_name': 'persona_189.txt', 'file_type': 'text/plain', 'file_size': 236, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="A geochronologist specializing in potassium-argon dating methods, likely employed in the field of geology, archaeology, or paleontology, and focused on reconstructing the Earth's history through radiometric dating of rocks and minerals.", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='65907e55-a756-44ea-a850-324ee3987bf7', embedding=None, metadata={'file_path': '/content/data/persona_1890.txt', 'file_name': 'persona_1890.txt', 'file_type': 'text/plain', 'file_size': 246, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A conservationist and environmental advocate focused on raising public awareness about ecological issues and informing policy decisions to mitigate human impact on the natural world, likely with a background in a field such as biology or ecology.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ce69e811-27cb-498b-a6e6-5752fdabaff8', embedding=None, metadata={'file_path': '/content/data/persona_1891.txt', 'file_name': 'persona_1891.txt', 'file_type': 'text/plain', 'file_size': 159, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A public health researcher focused on dietary intake patterns and nutritional epidemiology, likely affiliated with a government agency or academic institution.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='acaaca65-9956-42f7-9d0b-0c6937aca18e', embedding=None, metadata={'file_path': '/content/data/persona_1892.txt', 'file_name': 'persona_1892.txt', 'file_type': 'text/plain', 'file_size': 298, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A technical writer specializing in automotive components, likely with a background in mechanical engineering or a related field, or an automotive industry professional, such as a tire technician or a salesperson at a tire shop, seeking to educate customers about tire composition and manufacturing.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7207e13a-80cc-4b89-9a6b-d5599ba2795e', embedding=None, metadata={'file_path': '/content/data/persona_1893.txt', 'file_name': 'persona_1893.txt', 'file_type': 'text/plain', 'file_size': 152, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A historian specializing in colonial American conflicts or an American studies scholar focused on Native American history and the impact of colonialism.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='9029743b-c170-472f-aecb-24fa485180ad', embedding=None, metadata={'file_path': '/content/data/persona_1894.txt', 'file_name': 'persona_1894.txt', 'file_type': 'text/plain', 'file_size': 196, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An archaeologist or paleontologist specializing in the application of radiometric and relative dating techniques to reconstruct historical timelines of ancient civilizations and geological events.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ccc74d18-ecc9-4f57-a073-950127519559', embedding=None, metadata={'file_path': '/content/data/persona_1895.txt', 'file_name': 'persona_1895.txt', 'file_type': 'text/plain', 'file_size': 66, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A physicist specializing in laser technology and its applications.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='8a5631b7-1af2-4de2-944b-8371edeeaaf6', embedding=None, metadata={'file_path': '/content/data/persona_1896.txt', 'file_name': 'persona_1896.txt', 'file_type': 'text/plain', 'file_size': 211, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='An environmental sustainability-focused AI researcher or specialist who advocates for the integration of artificial intelligence in tackling global environmental challenges and mitigating its own climate impact.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='cde6b9c6-5c24-447f-822d-a5a08099e3bf', embedding=None, metadata={'file_path': '/content/data/persona_1897.txt', 'file_name': 'persona_1897.txt', 'file_type': 'text/plain', 'file_size': 183, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A physics student, likely at the undergraduate level, possibly taking a course in nuclear physics, who is working on problem sets and seeking help with a specific homework assignment.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a1597898-119e-4817-93c7-2e7d01e83795', embedding=None, metadata={'file_path': '/content/data/persona_1898.txt', 'file_name': 'persona_1898.txt', 'file_type': 'text/plain', 'file_size': 145, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='A biology or immunology educator or a health writer focused on creating informative content for a general audience about the human immune system.', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  ...]

# %% [markdown]
# Now we have a list of `Document` objects, we can use the `IngestionPipeline` to create nodes from the documents and prepare them for the `QueryEngine`. We will use the `SentenceSplitter` to split the documents into smaller chunks and the `HuggingFaceEmbedding` to embed the chunks.

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline

# create the pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(),
        HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5"),
    ]
)

# run the pipeline sync or async
nodes = await pipeline.arun(documents=documents[:10])
nodes
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [TextNode(id_='edab54ed-ef94-41fb-9add-6cc21d814314', embedding=[-0.0012166907545179129, 0.01964835450053215, 0.04393022134900093, -0.0022480515763163567, -0.01840735413134098, -0.017943933606147766, 0.009850618429481983, 0.03162042796611786, -0.06904760748147964, -0.04868912324309349, 0.0006960140890441835, -0.039564911276102066, -0.04958917200565338, 0.03078899346292019, -0.0216880664229393, -0.0027349276933819056, 0.009126023389399052, 0.08719330281019211, 0.008962404914200306, 0.012264067307114601, 0.014265610836446285, -0.0663817822933197, 0.03564688563346863, -0.019090434536337852, -0.029022280126810074, -0.0002521576243452728, 0.016371168196201324, -0.006577853579074144, -0.01683872938156128, -0.11301668733358383, -0.0613473579287529, 0.009758847765624523, -0.026674138382077217, 0.014211314730346203, 0.06158553063869476, 0.010618181899189949, 0.013383880257606506, 0.0661582350730896, 0.007938399910926819, 0.017128722742199898, 0.02946525812149048, 0.016287578269839287, -0.025776337832212448, 0.039969224482774734, 0.06221700459718704, -0.0143026327714324, 0.00010034911247203127, -0.01347463857382536, 0.0092460997402668, -0.006291808560490608, 0.026654286310076714, 0.005326927173882723, -0.04016689956188202, -0.003824722021818161, -0.009306668303906918, 0.12138164788484573, 0.0925208330154419, 0.03355773538351059, -0.020379938185214996, 0.04535149782896042, 0.036885518580675125, 0.02111445926129818, -0.18992295861244202, 0.055461134761571884, -0.01283671148121357, 0.013322344981133938, -0.08828184008598328, 0.004321655724197626, -0.009587747044861317, -0.03797062486410141, -0.042976073920726776, 0.014823447912931442, -0.05016675963997841, 0.010955963283777237, 0.037641145288944244, -0.08306688815355301, 0.03876529261469841, 0.01180720143020153, -0.07413017004728317, 0.011005847714841366, 0.040997233241796494, -0.01501508243381977, -0.009427177719771862, -0.04484483227133751, -0.009596306830644608, 0.013063805177807808, -0.0067699444480240345, 0.005632179789245129, -0.019296765327453613, 0.001408410258591175, -0.021571487188339233, -0.07425712049007416, 0.05647488310933113, -0.0035752400290220976, -0.023849153891205788, -0.027712102979421616, 0.022907759994268417, 0.04169970378279686, -0.014327057637274265, 0.4145660400390625, -0.021069778129458427, 0.009426705539
035752400290220976, -0.023849153891205788, -0.027712102979421616, 0.022907759994268417, 0.04169970378279686, -0.014327057637274265, 0.4145660400390625, -0.021069778129458427, 0.009426705539226532, 0.03323746100068092, -0.02200036495923996, 0.02922244556248188, 0.02175293117761612, -0.0158701092004776, -0.02552446536719799, -0.036326680332422256, -0.006469127256423235, -0.013789573684334755, 0.0029618677217513323, -0.05544804781675339, -0.014887450262904167, 0.10115818679332733, -0.002526266034692526, 0.038392651826143265, 0.07570239901542664, 0.002035286743193865, 0.0014736342709511518, 0.026450250297784805, -0.006710689514875412, 0.024879977107048035, 0.027458079159259796, -0.03396255150437355, -0.06862200051546097, -0.009689074009656906, 0.052289146929979324, 0.0011179086286574602, 0.013458600267767906, -0.04269835725426674, 0.0902978703379631, -0.04236117750406265, 0.03664664179086685, -0.014839391224086285, 0.04199981316924095, 0.030530355870723724, -0.02882097102701664, 0.037996768951416016, 0.019688883796334267, 0.0092760119587183, -0.00456989835947752, -0.03832633048295975, 0.020215783268213272, -0.10534800589084625, 0.039981771260499954, 0.01081104576587677, -0.02301017753779888, 0.014636309817433357, -0.011900256387889385, -0.0008839758229441941, -0.015807710587978363, -0.060600731521844864, 0.060335345566272736, 0.027676379308104515, 0.003066964680328965, 0.06893238425254822, 0.038687415421009064, -0.05370159074664116, 0.05084344372153282, 0.021472539752721786, -0.10854529589414597, 0.03890175372362137, 0.02543354034423828, 0.02992544323205948, -0.07675382494926453, 0.00380528112873435, 0.0019171948079019785, 0.023697910830378532, -0.005417023319751024, 0.05328604206442833, 0.044684551656246185, -0.05122538283467293, 0.060366190969944, 0.06764762103557587, -0.0028278131503611803, -0.013785071671009064, -0.003540336387231946, 0.0418323166668 ...

# %% [markdown]
# As, you can see, we have created a list of `Node` objects, which are just chunks of text from the original documents. Let's explore how we can add these nodes to a vector store.
#
# ### Storing and indexing documents
#
# Since we are using an ingestion pipeline, we can directly attach a vector store to the pipeline to populate it.
# In this case, we will use `Chroma` to store our documents.
# Let's run the pipeline again with the vector store attached.
# The `IngestionPipeline` caches the operations so this should be fast!

# %%
import chromadb
from llama_index.vector_stores.chroma import ChromaVectorStore

db = chromadb.PersistentClient(path="./alfred_chroma_db")
chroma_collection = db.get_or_create_collection(name="alfred")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(),
        HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5"),
    ],
    vector_store=vector_store,
)

nodes = await pipeline.arun(documents=documents[:10])
len(nodes)
# Out:
# 10

# %%
nodes[0]
# Out:
# TextNode(id_='599a8a1c-d7b3-4390-a644-d5bfd5f979c4', embedding=[-0.0012166907545179129, 0.01964835450053215, 0.04393022134900093, -0.0022480515763163567, -0.01840735413134098, -0.017943933606147766, 0.009850618429481983, 0.03162042796611786, -0.06904760748147964, -0.04868912324309349, 0.0006960140890441835, -0.039564911276102066, -0.04958917200565338, 0.03078899346292019, -0.0216880664229393, -0.0027349276933819056, 0.009126023389399052, 0.08719330281019211, 0.008962404914200306, 0.012264067307114601, 0.014265610836446
# %% [markdown]
# We can create a `VectorStoreIndex` from the vector store and use it to query the documents by passing the vector store and embedding model to the `from_vector_store()` method.

# %%
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding


embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
index = VectorStoreIndex.from_vector_store(
    vector_store=vector_store, embed_model=embed_model
)

# %% [markdown]
# We don't need to worry about persisting the index to disk, as it is automatically saved within the `ChromaVectorStore` object and the passed directory path.
#
# ### Querying the index
#
# Now that we have our index, we can use it to query the documents.
# Let's create a `QueryEngine` from the index and use it to query the documents using a specific response mode.

# %%
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
import nest_asyncio

nest_asyncio.apply()  # This is needed to run the query engine
llm = HuggingFaceInferenceAPI(model_name="Qwen/Qwen2.5-Coder-32B-Instruct")
query_engine = index.as_query_engine(
    llm=llm,
    response_mode="tree_summarize",
)
response = query_engine.query(
    "Respond using a persona that describes author and travel experiences?"
)
response
# Out:
# Response(response='An individual deeply immersed in the study of Cypriot culture, history, and society, having dedicated significant time to research and reside in Cyprus. This person has gained a profound understanding of the local customs and way of life, making them a valuable resource for those interested in the intricacies of Cypriot heritage.', source_nodes=[NodeWithScore(node=TextNode(id_='ee832d0b-4226-4741-a897-fb53958e812f', embedding=None, metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='425a01c7-2902-4f3c-83c3-e080226fa3b7', node_type='4', metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='007b9c61452893681b4d57be1a04e3f40bb96e791133c7e914358db29dd95d34')}, metadata_template='{key}: {value}', metadata_separator='\n', text='An anthropologist or a cultural expert interested in the intricacies of Cypriot culture, history, and society, particularly someone who has spent considerable time researching and living in Cyprus to gain a deep understanding of its people, customs, and way of life.', mimetype='text/plain', start_char_idx=0, end_char_idx=266, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.5519541069693891), NodeWithScore(node=TextNode(id_='4c8df2ed-76bf-4ad3-bdd2-f393f739bcff', embedding=None, metadata={'file_path': '/content/data/persona_1000.txt', 'file_name': 'persona_1000.txt', 'file_type': 'text/plain', 'file_size': 133, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f7c14d04-df0c-4d85-bd12-8ab593c5fa77', node_type='4', metadata={'file_path': '/content/data/persona_1000.txt', 'file_name': 'persona_1000.txt', 'file_type': 'text/plain', 'file_size': 133, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='50764a7756984d8e5bf68aa3813612ede536f6be052987eb05614bd0d6b82b20')}, metadata_template='{key}: {value}', metadata_separator='\n', text='A pulmonologist or respiratory specialist with a strong interest in educating patients about the respiratory system and its diseases.', mimetype='text/plain', start_char_idx=0, end_char_idx=133, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.5036323232983888)], metadata={'ee832d0b-4226-4741-a897-fb53958e812f': {'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, '4c8df2ed-76bf-4ad3-bdd2-f393f739bcff': {'file_path': '/content/data/persona_1000.txt', 'file_name': 'persona_1000.txt', 'file_type': 'text/plain', 'file_size': 133, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}})

# %%
query_engine.query("What is the meaning of life?")
# Out:
# Response(response='The meaning of life is a profound and philosophical question that has puzzled humans for centuries. Different individuals and cultures have their own interpretations and beliefs about what gives life meaning. For the anthropologist or cultural expert, the meaning of life might be found in the rich tapestry of human experiences, traditions, and the interconnectedness of all life. On the other hand, for the web developer or student, the meaning of life could be seen through the lens of creation, problem-solving, and the impact of technology on society. Ultimately, the meaning of life is a deeply personal and subjective concept.', source_nodes=[NodeWithScore(node=TextNode(id_='ee832d0b-4226-4741-a897-fb53958e812f', embedding=None, metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='425a01c7-2902-4f3c-83c3-e080226fa3b7', node_type='4', metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='007b9c61452893681b4d57be1a04e3f40bb96e791133c7e914358db29dd95d34')}, metadata_template='{key}: {value}', metadata_separator='\n', text='An anthropologist or a cultural expert interested in the intricacies of Cypriot culture, history, and society, particularly someone who has spent considerable time researching and living in Cyprus to gain a deep understanding of its people, customs, and way of life.', mimetype='text/plain', start_char_idx=0, end_char_idx=266, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.39488336867057416), NodeWithScore(node=TextNode(id_='470312dc-a85e-46fc-aa07-02e30a3ed832', embedding=None, metadata={'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1ae5708c-b5e1-468c-9cfd-6ed20d878085', node_type='4', metadata={'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='754a355df5527bb2f3740ee60ddd6be2c1acb8fbc49c0a52a58d6d84bcb01e41')}, metadata_template='{key}: {value}', metadata_separator='\n', text='A web developer or a web development student, likely in the early stages of their learning or career, with a strong focus on HTML, CSS, and website building.', mimetype='text/plain', start_char_idx=0, end_char_idx=157, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.3833244310289481)], metadata={'ee832d0b-4226-4741-a897-fb53958e812f': {'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, '470312dc-a85e-46fc-aa07-02e30a3ed832': {'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}})

# %%
query_engine = index.as_query_engine(
    llm=llm,
    response_mode="compact",
)
query_engine.query("What is the meaning of life?")
# Out:
# Response(response="The meaning of life is a profound and philosophical question that has been explored by many cultures, scholars, and individuals throughout history. For someone deeply immersed in Cypriot culture, the meaning of life might be intertwined with the island's rich history, its people's resilience, and the importance of community and tradition. On the other hand, for a web developer or student, the meaning of life could be seen through the lens of creation, problem-solving, and the impact of technology on society. Both perspectives highlight the importance of understanding one's place in the world and the values that guide one's actions and beliefs.", source_nodes=[NodeWithScore(node=TextNode(id_='ee832d0b-4226-4741-a897-fb53958e812f', embedding=None, metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='425a01c7-2902-4f3c-83c3-e080226fa3b7', node_type='4', metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='007b9c61452893681b4d57be1a04e3f40bb96e791133c7e914358db29dd95d34')}, metadata_template='{key}: {value}', metadata_separator='\n', text='An anthropologist or a cultural expert interested in the intricacies of Cypriot culture, history, and society, particularly someone who has spent considerable time researching and living in Cyprus to gain a deep understanding of its people, customs, and way of life.', mimetype='text/plain', start_char_idx=0, end_char_idx=266, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.39488336867057416), NodeWithScore(node=TextNode(id_='470312dc-a85e-46fc-aa07-02e30a3ed832', embedding=None, metadata={'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1ae5708c-b5e1-468c-9cfd-6ed20d878085', node_type='4', metadata={'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='754a355df5527bb2f3740ee60ddd6be2c1acb8fbc49c0a52a58d6d84bcb01e41')}, metadata_template='{key}: {value}', metadata_separator='\n', text='A web developer or a web development student, likely in the early stages of their learning or career, with a strong focus on HTML, CSS, and website building.', mimetype='text/plain', start_char_idx=0, end_char_idx=157, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.3833244310289481)], metadata={'ee832d0b-4226-4741-a897-fb53958e812f': {'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, '470312dc-a85e-46fc-aa07-02e30a3ed832': {'file_path': '/content/data/persona_1001.txt', 'file_name': 'persona_1001.txt', 'file_type': 'text/plain', 'file_size': 157, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}})

# %% [markdown]
# ## Evaluation and observability
#
# LlamaIndex provides **built-in evaluation tools to assess response quality.**
# These evaluators leverage LLMs to analyze responses across different dimensions.
# We can now check if the query is faithful to the original persona.

# %%
from llama_index.core.evaluation import FaithfulnessEvaluator

# query index
evaluator = FaithfulnessEvaluator(llm=llm)
eval_result = evaluator.evaluate_response(response=response)
eval_result.passing
# Out:
# False

# %% [markdown]
# If one of these LLM based evaluators does not give enough context, we can check the response using the Arize Phoenix tool, after creating an account at [LlamaTrace](https://llamatrace.com/login) and generating an API key.

# %%
import llama_index
import os

PHOENIX_API_KEY = "ddf8491f1ae9ec21e51:17be80d"
os.environ["OTEL_EXPORTER_OTLP_HEADERS"] = f"api_key={PHOENIX_API_KEY}"
llama_index.core.set_global_handler(
    "arize_phoenix", endpoint="https://llamatrace.com/v1/traces"
)

# %% [markdown]
# Now, we can query the index and see the response in the Arize Phoenix tool.

# %%
response = query_engine.query(
    "What is the name of the someone that is interested in AI and techhnology?"
)
response
# Out:
# Response(response="The information provided does not mention anyone interested in AI and technology. The details given are about an anthropologist or cultural expert focusing on Cypriot culture and a local art historian specializing in 19th-century American art and Cincinnati's cultural heritage.", source_nodes=[NodeWithScore(node=TextNode(id_='ee832d0b-4226-4741-a897-fb53958e812f', embedding=None, metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='425a01c7-2902-4f3c-83c3-e080226fa3b7', node_type='4', metadata={'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='007b9c61452893681b4d57be1a04e3f40bb96e791133c7e914358db29dd95d34')}, metadata_template='{key}: {value}', metadata_separator='\n', text='An anthropologist or a cultural expert interested in the intricacies of Cypriot culture, history, and society, particularly someone who has spent considerable time researching and living in Cyprus to gain a deep understanding of its people, customs, and way of life.', mimetype='text/plain', start_char_idx=0, end_char_idx=266, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.4556749939091504), NodeWithScore(node=TextNode(id_='84f3a660-4b4f-4df0-8bfb-7c9d2d5d2bc1', embedding=None, metadata={'file_path': '/content/data/persona_0.txt', 'file_name': 'persona_0.txt', 'file_type': 'text/plain', 'file_size': 132, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0a7e4f2f-32cb-41f8-9c1d-db352c56379e', node_type='4', metadata={'file_path': '/content/data/persona_0.txt', 'file_name': 'persona_0.txt', 'file_type': 'text/plain', 'file_size': 132, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, hash='ef60fc9d6905eaa6290693885df02312e3ca1ce7970073439b8a6a6f25a50905')}, metadata_template='{key}: {value}', metadata_separator='\n', text='A local art historian and museum professional interested in 19th-century American art and the local cultural heritage of Cincinnati.', mimetype='text/plain', start_char_idx=0, end_char_idx=132, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.4342714565548076)], metadata={'ee832d0b-4226-4741-a897-fb53958e812f': {'file_path': '/content/data/persona_1.txt', 'file_name': 'persona_1.txt', 'file_type': 'text/plain', 'file_size': 266, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}, '84f3a660-4b4f-4df0-8bfb-7c9d2d5d2bc1': {'file_path': '/content/data/persona_0.txt', 'file_name': 'persona_0.txt', 'file_type': 'text/plain', 'file_size': 132, 'creation_date': '2025-06-24', 'last_modified_date': '2025-06-24'}})

# %% [markdown]
# We can then go to the [LlamaTrace](https://llamatrace.com/login) and explore the process and response.

# %% [markdown]
# ![arize-phoenix](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/unit2/llama-index/arize.png)
